# %%
# from huggingface_hub import notebook_login
# notebook_login()

# %%
import sys
sys.path = ["/home/wukailu/single-stable-dreamfusion"] + sys.path
import torch
torch.cuda.set_device(1)
torch.cuda.empty_cache()

# %%
#@markdown ####**Training Settings:**
Prompt_text = "a DSLR photo of a green ficus" #@param {type: 'string'}
Training_iters = 5000 #@param {type: 'integer'}
Learning_rate = 1e-3 #@param {type: 'number'}
Training_nerf_resolution = 64  #@param {type: 'integer'}
# CUDA_ray = True #@param {type: 'boolean'}
# View_dependent_prompt = True #@param {type: 'boolean'}
# FP16 = True #@param {type: 'boolean'}
Seed = 0 #@param {type: 'integer'}
Lambda_entropy = 1e-4 #@param {type: 'number'}
Max_steps = 512 #@param {type: 'number'}
Checkpoint = 'latest' #@param {type: 'string'}

#@markdown ---

#@markdown ####**Output Settings:**
Workspace = "trial" #@param{type: 'string'}
# Save_mesh = True #@param {type: 'boolean'}

# processings
Prompt_text = "'" + Prompt_text + "'"

# %%
# %run main.py -O --text {Prompt_text} --workspace {Workspace} --iters {Training_iters} --lr {Learning_rate} --w {Training_nerf_resolution} --h {Training_nerf_resolution} --seed {Seed} --lambda_entropy {Lambda_entropy} --ckpt {Checkpoint} --save_mesh --max_steps {Max_steps}
# Out:
# Namespace(H=800, O=True, O2=False, W=800, albedo_iters=1000, angle_front=60, angle_overhead=30, backbone='grid', bg_radius=1.4, bound=1, ckpt='latest', cuda_ray=True, density_thresh=10, dir_text=True, dt_gamma=0, eval_interval=10, fovy=60, fovy_range=[40, 70], fp16=True, gui=False, guidance='stable-diffusion', h=64, iters=5000, jitter_pose=False, lambda_entropy=0.0001, lambda_opacity=0, lambda_orient=0.01, lambda_smooth=0, light_phi=0, light_theta=60, lr=0.001, max_ray_batch=4096, max_spp=1, max_steps=512, min_near=0.1, negative='', num_steps=64, radius=3, radius_range=[1.0, 1.5], save_mesh=True, seed=0, suppress_face=False, test=False, text='a DSLR photo of a green ficus', uniform_sphere_rate=0.5, update_extra_interval=16, upsample_steps=64, w=64, workspace='trial')
# /home/wukailu/single-stable-dreamfusion/frameworks/nerf/modules/dvgo_coarse.py:27: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer('xyz_min', torch.tensor(self.params['xyz_min']).float())
# /home/wukailu/single-stable-dreamfusion/frameworks/nerf/modules/dvgo_coarse.py:28: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer('xyz_max', torch.tensor(self.params['xyz_max']).float())
# dvgo: voxel_size       tensor(0.0089)
# dvgo: world_size       tensor([102, 160, 249])
# dvgo: voxel_size_ratio tensor(1.)
# posbase_pe is 0!
# NeRFNetwork_Kailu(
#   (main_net): DVGO_Fine(
#     (metrics): ModuleDict(
#       (psnr): PSNR()
#     )
#     (rgbnet): BasicMLP(
#       (net): Sequential(
#         (0): Linear(in_features=39, out_features=128, bias=True)
#         (1): ReLU(inplace=True)
#         (2): Sequential(
#           (0): Linear(in_features=128, out_features=128, bias=True)
#           (1): ReLU(inplace=True)
#         )
#         (3): Linear(in_features=128, out_features=3, bias=True)
#       )
#     )
#   )
#   (encoder_bg): FreqEncoder: input_dim=3 degree=6 output_dim=39
#   (bg_net): MLP(
#     (net): ModuleList(
#       (0): ResBlock(
#         (dense): Linear(in_features=39, out_features=64, bias=True)
#         (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (activation): SiLU()
#         (skip): Linear(in_features=39, out_features=64, bias=False)
#       )
#       (1): Linear(in_features=64, out_features=3, bias=True)
#     )
#   )
# )
# [INFO] try to load hugging face access token from the default place, make sure you have run `huggingface-cli login`.
# [INFO] loading stable diffusion...
# [INFO] loaded stable diffusion!
# [INFO] Trainer: df | 2022-11-14_12-36-35 | cuda | fp16 | trial
# [INFO] #parameters: 48791558
# [INFO] Loading latest checkpoint ...
# [WARN] No checkpoint found, model randomly initialized.
# ==> Start Training trial Epoch 1, lr=0.001000 ...
# loss=0.0000 (0.0000), lr=0.000955: : 100% 100/100 [01:44<00:00,  1.05s/it]
# ==> Finished Epoch 1.
# ==> Start Training trial Epoch 2, lr=0.000955 ...
# loss=0.0000 (0.0000), lr=0.000912: : 100% 100/100 [01:44<00:00,  1.05s/it]
# ==> Finished Epoch 2.
# ==> Start Training trial Epoch 3, lr=0.000912 ...
# loss=0.0000 (0.0000), lr=0.000871: : 100% 100/100 [01:44<00:00,  1.04s/it]
# ==> Finished Epoch 3.
# ==> Start Training trial Epoch 4, lr=0.000871 ...
# loss=0.0000 (0.0000), lr=0.000832: : 100% 100/100 [01:44<00:00,  1.05s/it]
# ==> Finished Epoch 4.
# ==> Start Training trial Epoch 5, lr=0.000832 ...
# loss=0.0000 (0.0000), lr=0.000794: : 100% 100/100 [01:44<00:00,  1.05s/it]
# ==> Finished Epoch 5.
# ==> Start Training trial Epoch 6, lr=0.000794 ...
# loss=0.0000 (0.0000), lr=0.000759: : 100% 100/100 [01:44<00:00,  1.04s/it]
# ==> Finished Epoch 6.
# ==> Start Training trial Epoch 7, lr=0.000759 ...
# loss=0.0000 (0.0000), lr=0.000724: : 100% 100/100 [01:44<00:00,  1.05s/it]
# ==> Finished Epoch 7.
# ==> Start Training trial Epoch 8, lr=0.000724 ...
# loss=0.0000 (0.0000), lr=0.000692: : 100% 100/100 [01:44<00:00,  1.04s/it]
# ==> Finished Epoch 8.
# ==> Start Training trial Epoch 9, lr=0.000692 ...
# loss=0.0000 (0.0000), lr=0.000661: : 100% 100/100 [01:44<00:00,  1.05s/it]
# ==> Finished Epoch 9.
# ==> Start Training trial Epoch 10, lr=0.000661 ...
# loss=0.0003 (0.0000), lr=0.000631: : 100% 100/100 [01:45<00:00,  1.05s/it]
# ==> Finished Epoch 10.
# ++> Evaluate trial at epoch 10 ...
# loss=0.0000 (0.0000): : 100% 5/5 [00:05<00:00,  1.12s/it]
# ++> Evaluate epoch 10 Finished.
# [INFO] New best result: None --> 1.5114075722522102e-05
# ==> Start Training trial Epoch 11, lr=0.000631 ...
# loss=0.0001 (0.0002), lr=0.000603: : 100% 100/100 [01:51<00:00,  1.12s/it]
# ==> Finished Epoch 11.
# ==> Start Training trial Epoch 12, lr=0.000603 ...
# loss=0.0002 (0.0002), lr=0.000575: : 100% 100/100 [01:53<00:00,  1.13s/it]
# ==> Finished Epoch 12.
# ==> Start Training trial Epoch 13, lr=0.000575 ...
# loss=0.0002 (0.0002), lr=0.000550: : 100% 100/100 [01:52<00:00,  1.13s/it]
# ==> Finished Epoch 13.
# ==> Start Training trial Epoch 14, lr=0.000550 ...
# loss=0.0002 (0.0002), lr=0.000525: : 100% 100/100 [01:52<00:00,  1.12s/it]
# ==> Finished Epoch 14.
# ==> Start Training trial Epoch 15, lr=0.000525 ...
# loss=0.0002 (0.0002), lr=0.000501: : 100% 100/100 [01:51<00:00,  1.11s/it]
# ==> Finished Epoch 15.
# ==> Start Training trial Epoch 16, lr=0.000501 ...
# loss=0.0003 (0.0002), lr=0.000479: : 100% 100/100 [01:53<00:00,  1.13s/it]
# ==> Finished Epoch 16.
# ==> Start Training trial Epoch 17, lr=0.000479 ...
# loss=0.0000 (0.0002), lr=0.000457: : 100% 100/100 [01:52<00:00,  1.13s/it]
# ==> Finished Epoch 17.
# ==> Start Training trial Epoch 18, lr=0.000457 ...
# loss=0.0002 (0.0002), lr=0.000437: : 100% 100/100 [01:52<00:00,  1.13s/it]
# ==> Finished Epoch 18.
# ==> Start Training trial Epoch 19, lr=0.000437 ...
# loss=0.0002 (0.0002), lr=0.000417: : 100% 100/100 [01:53<00:00,  1.14s/it]
# ==> Finished Epoch 19.
# ==> Start Training trial Epoch 20, lr=0.000417 ...
# loss=0.0002 (0.0002), lr=0.000398: : 100% 100/100 [01:52<00:00,  1.13s/it]
# ==> Finished Epoch 20.
# ++> Evaluate trial at epoch 20 ...
# loss=0.0000 (0.0000): : 100% 5/5 [00:05<00:00,  1.11s/it]
# ++> Evaluate epoch 20 Finished.
# ==> Start Training trial Epoch 21, lr=0.000398 ...
# loss=0.0002 (0.0002), lr=0.000380: : 100% 100/100 [01:51<00:00,  1.12s/it]
# ==> Finished Epoch 21.
# ==> Start Training trial Epoch 22, lr=0.000380 ...
# loss=0.0002 (0.0002), lr=0.000363: : 100% 100/100 [01:52<00:00,  1.12s/it]
# ==> Finished Epoch 22.
# ==> Start Training trial Epoch 23, lr=0.000363 ...
# loss=0.0002 (0.0002), lr=0.000347: : 100% 100/100 [01:52<00:00,  1.13s/it]
# ==> Finished Epoch 23.
# ==> Start Training trial Epoch 24, lr=0.000347 ...
# loss=0.0002 (0.0002), lr=0.000331: : 100% 100/100 [01:52<00:00,  1.13s/it]
# ==> Finished Epoch 24.
# ==> Start Training trial Epoch 25, lr=0.000331 ...
# loss=0.0000 (0.0002), lr=0.000316: : 100% 100/100 [01:53<00:00,  1.14s/it]
# ==> Finished Epoch 25.
# ==> Start Training trial Epoch 26, lr=0.000316 ...
# loss=0.0002 (0.0002), lr=0.000302: : 100% 100/100 [01:52<00:00,  1.12s/it]
# ==> Finished Epoch 26.
# ==> Start Training trial Epoch 27, lr=0.000302 ...
# loss=0.0002 (0.0002), lr=0.000288: : 100% 100/100 [01:52<00:00,  1.13s/it]
# ==> Finished Epoch 27.
# ==> Start Training trial Epoch 28, lr=0.000288 ...
# loss=0.0002 (0.0002), lr=0.000275: : 100% 100/100 [01:53<00:00,  1.14s/it]
# ==> Finished Epoch 28.
# ==> Start Training trial Epoch 29, lr=0.000275 ...
# loss=0.0002 (0.0002), lr=0.000263: : 100% 100/100 [01:52<00:00,  1.13s/it]
# ==> Finished Epoch 29.
# ==> Start Training trial Epoch 30, lr=0.000263 ...
# loss=0.0003 (0.0002), lr=0.000251: : 100% 100/100 [01:53<00:00,  1.14s/it]
# ==> Finished Epoch 30.
# ++> Evaluate trial at epoch 30 ...
# loss=0.0000 (0.0000): : 100% 5/5 [00:05<00:00,  1.10s/it]
# ++> Evaluate epoch 30 Finished.
# ==> Start Training trial Epoch 31, lr=0.000251 ...
# loss=0.0000 (0.0002), lr=0.000240: : 100% 100/100 [01:52<00:00,  1.12s/it]
# ==> Finished Epoch 31.
# ==> Start Training trial Epoch 32, lr=0.000240 ...
# loss=0.0002 (0.0002), lr=0.000229: : 100% 100/100 [01:52<00:00,  1.12s/it]
# ==> Finished Epoch 32.
# ==> Start Training trial Epoch 33, lr=0.000229 ...
# loss=0.0002 (0.0002), lr=0.000219: : 100% 100/100 [01:54<00:00,  1.14s/it]
# ==> Finished Epoch 33.
# ==> Start Training trial Epoch 34, lr=0.000219 ...
# loss=0.0003 (0.0002), lr=0.000209: : 100% 100/100 [01:54<00:00,  1.14s/it]
# ==> Finished Epoch 34.
# ==> Start Training trial Epoch 35, lr=0.000209 ...
# loss=0.0000 (0.0002), lr=0.000200: : 100% 100/100 [01:53<00:00,  1.13s/it]
# ==> Finished Epoch 35.
# ==> Start Training trial Epoch 36, lr=0.000200 ...
# loss=0.0002 (0.0002), lr=0.000191: : 100% 100/100 [01:52<00:00,  1.13s/it]
# ==> Finished Epoch 36.
# ==> Start Training trial Epoch 37, lr=0.000191 ...
# loss=0.0002 (0.0002), lr=0.000182: : 100% 100/100 [01:52<00:00,  1.13s/it]
# ==> Finished Epoch 37.
# ==> Start Training trial Epoch 38, lr=0.000182 ...
# loss=0.0002 (0.0002), lr=0.000174: : 100% 100/100 [01:51<00:00,  1.11s/it]
# ==> Finished Epoch 38.
# ==> Start Training trial Epoch 39, lr=0.000174 ...
# loss=0.0000 (0.0002), lr=0.000166: : 100% 100/100 [01:51<00:00,  1.12s/it]
# ==> Finished Epoch 39.
# ==> Start Training trial Epoch 40, lr=0.000166 ...
# loss=0.0002 (0.0002), lr=0.000158: : 100% 100/100 [01:52<00:00,  1.12s/it]
# ==> Finished Epoch 40.
# ++> Evaluate trial at epoch 40 ...
# loss=0.0000 (0.0000): : 100% 5/5 [00:05<00:00,  1.10s/it]
# ++> Evaluate epoch 40 Finished.
# ==> Start Training trial Epoch 41, lr=0.000158 ...
# loss=0.0003 (0.0002), lr=0.000151: : 100% 100/100 [01:52<00:00,  1.12s/it]
# ==> Finished Epoch 41.
# ==> Start Training trial Epoch 42, lr=0.000151 ...
#   0% 0/100 [00:00<?, ?it/s]

# %%
#@title (optional) testing 
# %run main.py -O --test --workspace {Workspace_test} --save_mesh

# %%
#@title display RGB video
import os
import glob
from IPython.display import HTML
from base64 import b64encode

def get_latest_file(path):
    dir_list = glob.glob(path)
    dir_list.sort(key=lambda x: os.path.getmtime(x))
    return dir_list[-1]

def show_video(video_path, video_width = 600):
   
    video_file = open(video_path, "r+b").read()
    video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"

    return HTML(f"""<video width={video_width} controls><source src="{video_url}"></video>""")
 
rgb_video = get_latest_file(os.path.join(Workspace, 'results', '*_rgb.mp4'))
show_video(rgb_video)
# Out:
# <video width=600 controls><source src="data:video/mp4;base64,..."></video>
